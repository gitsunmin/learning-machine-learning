# %%
# how to make class

class Man:
    def __init__(self, name):
        self.name = name
        print('initilized!')
    
    def hello(self):
        print('Hello ' + self.name + '!')

    def goodbye(self):
        print('Good-bye '+ self.name + '!')


m = Man('Gitsunmin')
m.hello()
m.goodbye()
# Out:
# initilized!
# Hello Gitsunmin!
# Good-bye Gitsunmin!

# %%
# how to use numpy

import numpy as np

x = np.array([1.0, 2.0, 3.0])
y = np.array([2.0, 4.0, 6.0])

print(x + y)

print(x - y)

print(x / y)

print(x /2.0)

A = np.array([[1, 2], [3, 4]])

print(A)

print(A.shape)

print(A.dtype)

B = np.array([[3, 0], [0, 6]])

print(A + B)

print(A * B)

X = np.array([[51, 55], [14, 19], [0, 4]])

print(X[0]) # [51, 55]

print(X[0][1]) # 55

for row in X:
    print(row)

X = X.flatten()

print(X)

print(X[np.array([0, 2, 4])]) # get index 0 and 2, 4
# Out:
# [3. 6. 9.]
# [-1. -2. -3.]
# [0.5 0.5 0.5]
# [0.5 1.  1.5]
# [[1 2]
#  [3 4]]
# (2, 2)
# int64
# [[ 4  2]
#  [ 3 10]]
# [[ 3  0]
#  [ 0 24]]
# [51 55]
# 55
# [51 55]
# [14 19]
# [0 4]
# [51 55 14 19  0  4]
# array([51, 14,  0])

# %%
# using matplotlib

import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1)
y = np.sin(x)

# 그래프 그리기
plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1) # 0에서 6까지 0.1 간격으로 생성
y1 = np.sin(x)
y2 = np.cos(x)

# 그래프 그리기
plt.plot(x, y1, label="sin")
plt.plot(x, y2, label="cos") # cos 함수는 점선으로 그리기
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin & cos')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('./../assests/mountain.webp')

plt.imshow(img)
plt.show()
